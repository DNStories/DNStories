# %%
import pandas as pd
import datetime
import seaborn as sns

# %%
d0 = pd.read_csv('recursive_summary (2).csv.gz', parse_dates=['created'])

# %%
d0.head(2)
# Out:
#                     created country  probe_count  total  same_asn  google  \
# 0 2017-04-30 00:00:00+00:00      AD           12   9755      6945     941
# 1 2017-05-31 00:00:00+00:00      AD           13  28263     21465    2968
#
#    quad9  cloudflare  other  same_asn_pct  google_pct  quad9_pct  \
# 0      0           0   1869            71          10          0
# 1      0           0   3830            76          11          0
#
#    cloudflare_pct  other_pct
# 0               0         19
# 1               0         14

# %%
d1 = pd.read_csv('regional_resolvers (2).csv.gz', parse_dates=['created'])

# %%
d1['open_res_pct'] = d1['google_pct'] + d1['quad9_pct'] + d1['cloudflare_pct']

# %%
d1.head(2)
# Out:
#                     created                     region  probe_count   total  \
# 0 2017-04-30 00:00:00+00:00  Australia and New Zealand          248  221103
# 1 2017-04-30 00:00:00+00:00               Central Asia           47   36157
#
#    same_asn  google  quad9  cloudflare   other  same_asn_pct  google_pct  \
# 0     73028   38974      0           0  109101            33          18
# 1     18204    5557      0           0   12396            50          15
#
#    quad9_pct  cloudflare_pct  other_pct
# 0          0               0         49
# 1          0               0         34

# %%
d1.groupby('region')['probe_count'].describe()
# Out:
#                                  count         mean         std     min  \
# region
# Australia and New Zealand         88.0   284.045455   30.008010   243.0
# Central Asia                      88.0    71.715909   13.707913    47.0
# Eastern Asia                      88.0   324.511364   78.885483   214.0
# Eastern Europe                    88.0  1575.170455   63.240323  1434.0
# Latin America and the Caribbean   88.0   342.386364   47.564459   246.0
# Melanesia                         88.0    10.738636    3.442447     6.0
# Micronesia                        88.0     9.295455    2.079783     5.0
# Northern Africa                   88.0    17.420455    5.066731    10.0
# Northern America                  88.0  1764.818182  301.834374  1271.0
# Northern Europe                   88.0  1441.000000   34.322339  1331.0
# Polynesia                         88.0     7.261364    1.227036     5.0
# South-eastern Asia                88.0   249.488636   51.198957   190.0
# ...

# %%
d1.groupby('region')['google_pct'].describe()
# Out:
#                                  count       mean       std   min    25%  \
# region
# Australia and New Zealand         88.0  14.215909  2.291658   8.0  13.00
# Central Asia                      88.0  22.875000  6.392906  12.0  18.75
# Eastern Asia                      88.0  15.215909  2.465620   8.0  14.00
# Eastern Europe                    88.0  20.113636  3.049145  12.0  18.00
# Latin America and the Caribbean   88.0  17.215909  4.044150   9.0  14.00
# Melanesia                         88.0  22.329545  4.343635  13.0  19.00
# Micronesia                        88.0  19.647727  7.762331   5.0  15.75
# Northern Africa                   88.0  21.079545  7.094148   7.0  15.00
# Northern America                  88.0  17.579545  2.871667  10.0  16.00
# Northern Europe                   88.0  18.000000  3.017192  11.0  16.00
# Polynesia                         88.0  13.579545  5.654256   2.0   7.75
# South-eastern Asia                88.0  22.284091  3.826552  14.0  19.00
# ...

# %%
# sns.catplot(d1, x='created', y='probe_count', col='region', col_wrap=2, kind='point')

# %%
sns.catplot(x='created', y='same_asn_pct', data=d1, kind='point', col='region', col_wrap=3)
# Out:
# /Users/sebastian/opt/anaconda3_2023/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='created', y='google_pct', data=d1, kind='point', col='region', col_wrap=3)
# Out:
# /Users/sebastian/opt/anaconda3_2023/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='created', y='open_res_pct', data=d1, kind='point', col='region', col_wrap=3)
# Out:
# /Users/sebastian/opt/anaconda3_2023/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
